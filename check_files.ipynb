# %% [markdown]
# # OFFERS MATHCED TO INDIVIDUALS

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# ## Read in profiles csv to df

# %%
df_profiles = pd.read_csv('profiles.csv', names=["sex", "age"])
df_profiles.head()
# Out:
#   sex  age
# 0   F   51
# 1   F   28
# 2   F   29
# 3   F   27
# 4   M   48

# %%
plt.figure(figsize=(6,5))
plt.hist(df_profiles.age)
plt.xlabel("age")
plt.ylabel("count")
plt.title("Histogram of ages")
plt.show();

# %%
plt.figure(figsize=(10,10))
plt.scatter(df_profiles.sex, df_profiles.age)
plt.xlabel("Sex")
plt.ylabel("Age")
plt.title("Age vs Sex")
plt.show()

# %% [markdown]
# ## Read in offers csv to df

# %%
df_offers = pd.read_csv('offers.csv')
df_offers
# Out:
#   offer_name  price  show_male  show_female  show_18_25  show_26_35  \
# 0          A      3       True        False        True       False
# 1          B      5       True        False        True        True
# 2          C      2      False         True        True       False
# 3          D      1       True         True       False        True
# 4          E      7       True        False        True       False
# 5          F      2       True         True       False        True
# 6          G      5      False         True        True       False
# 7          H      1       True         True       False        True
# 8          I      4       True        False        True        True
# 9          J      3      False         True       False       False
#
#    show_36_45  show_46_plus
# 0       False         False
# 1       False          True
# 2       False         False
# 3        True         False
# 4       False         False
# 5       False         False
# 6       False          True
# 7       False         False
# 8       False         False
# 9        True         False

# %% [markdown]
# ## Read in output csv to df

# %%
df_output = pd.read_csv('output.csv', names=["sex", "age", "offer_1", "offer_2", "offer_3", "offer_4", "offer_5", "offer_6", "offer_7", "offer_8", "offer_9", "offer_10"])
df_output
# Out:
#   sex  age offer_1 offer_2 offer_3 offer_4 offer_5  offer_6  offer_7  offer_8  \
# 0   F   51       G     NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 1   F   28       F       H       D     NaN     NaN      NaN      NaN      NaN
# 2   F   29       F       H       D     NaN     NaN      NaN      NaN      NaN
# 3   M   48       B     NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 4   M   27       B       I       F       H       D      NaN      NaN      NaN
#
#    offer_9  offer_10
# 0      NaN       NaN
# 1      NaN       NaN
# 2      NaN       NaN
# 3      NaN       NaN
# 4      NaN       NaN

# %% [markdown]
# ## Logic for assigning offers

# %%
combined_array = []

for i in range(len(df_profiles)):
    
    sex = df_profiles.iloc[i].sex
    age = df_profiles.iloc[i].age
    
    individual_array = [sex, age]
    
    match sex:
        
        case "M":

            match age:
                case _ if(age >= 18 and age <= 25):
                    individual_array.append("E")
                    individual_array.append("B")
                    individual_array.append("I")
                    individual_array.append("A")
                    
                case _ if(age >= 26 and age <= 35):
                    individual_array.append("B")
                    individual_array.append("I")
                    individual_array.append("F")
                    individual_array.append("H")
                    individual_array.append("D")
                    
                case _ if(age >= 36 and age <= 45):
                    individual_array.append("J")
                    individual_array.append("D")
                    
                case _ if(age >= 46):
                    individual_array.append("B")
            
        case "F":
            
            match age:
                case _ if(age >= 18 and age <= 25):
                    individual_array.append("G")
                    individual_array.append("C")
                    
                case _ if(age >= 26 and age <= 35):
                    individual_array.append("F")
                    individual_array.append("H")
                    individual_array.append("D")
                    
                case _ if(age >= 36 and age <= 45):
                    individual_array.append("J")
                    individual_array.append("D")
                    
                case _ if(age >= 46):
                    individual_array.append("G")
            
    combined_array.append(individual_array)
    
df_result = pd.DataFrame(combined_array)

df_result.head()
# Out:
#    0   1  2     3     4     5     6
# 0  F  51  G  None  None  None  None
# 1  F  28  F     H     D  None  None
# 2  F  29  F     H     D  None  None
# 3  F  27  F     H     D  None  None
# 4  M  48  B  None  None  None  None

# %% [markdown]
# ## Output result to CSV file

# %%
df_result.to_csv("result.csv", header=False, index=False)
